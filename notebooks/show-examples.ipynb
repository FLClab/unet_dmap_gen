# %%
import numpy
import os, glob
import random

from matplotlib import pyplot

# %%
files = glob.glob(os.path.join("../results/datamaps/PSD95-Bassoon/*.npy"))

file = random.choice(files)
image = numpy.load(file)

fig, ax = pyplot.subplots()
ax.imshow(image, vmin=0, vmax=1, cmap="Greys")
pyplot.show()
